# %%
import pandas as pd

# %%
df=pd.read_csv('./data/korean-idol.csv')

# %%
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df.shape
# Out:
# (15, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       15 non-null     object
#  1   그룹       14 non-null     object
#  2   소속사      15 non-null     object
#  3   성별       15 non-null     object
#  4   생년월일     15 non-null     object
#  5   키        13 non-null     float64
#  6   혈액형      15 non-null     object
#  7   브랜드평판지수  15 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# 이름         0
# 그룹         1
# 소속사        0
# 성별         0
# 생년월일       0
# 키          2
# 혈액형        0
# 브랜드평판지수    0
# dtype: int64

# %%
df[df['키'].isnull()]
# Out:
#     이름    그룹 소속사  성별        생년월일   키 혈액형  브랜드평판지수
# 7   소연   아이들  큐브  여자  1998-08-26 NaN   B  4668615
# 10  태연  소녀시대  SM  여자  1989-03-09 NaN   A  3918661

# %%
df[df['그룹'].isnull()]
# Out:
#      이름   그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2  강다니엘  NaN  커넥트  남자  1996-12-10  180.0   A  8273745

# %%
df[df['키'].notnull()]
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 14    슈가  방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df.isnull().sum()
# Out:
# 이름         0
# 그룹         1
# 소속사        0
# 성별         0
# 생년월일       0
# 키          2
# 혈액형        0
# 브랜드평판지수    0
# dtype: int64

# %%
len(df)
# Out:
# 15

# %%
(df.isnull().sum()/len(df)*100).plot(kind='bar') #비율 구하기 df.구하고 싶은 곳.더하기/개수*100
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
#데이터 프레임 전체의 null 갯수 확인 df.isnull().sum()
#특정열의 null인 데이터 확인 
#null인 데이터만 필터링 isnull(), df[df['특정열'].isnull()]
#null이 아닌 데이터만 필터링 notnull(), df[df['특정열'].notnull()]

# %%
# !pip install missingno

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

import missingno as msno

# %%
df0=df.set_index('이름')

# %%
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# JR     뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가    방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# 이름          object
# 그룹          object
# 소속사         object
# 성별          object
# 생년월일        object
# 키          float64
# 혈액형         object
# 브랜드평판지수      int64
# dtype: object

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
df[df.isnull().any(axis=1)]
#null이 있는 열이 어딨는지 확인할 때
#df.isnull().sum()
#null이 있는 전체 열 확인
#df[df.isnull().any(axis=1)]
# Out:
#       이름    그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   강다니엘   NaN  커넥트  남자  1996-12-10  180.0   A  8273745
# 7     소연   아이들   큐브  여자  1998-08-26    NaN   B  4668615
# 10    태연  소녀시대   SM  여자  1989-03-09    NaN   A  3918661

# %%
df[df['키'].isnull()] #키에 있는 null만 볼 때
# Out:
#     이름    그룹 소속사  성별        생년월일   키 혈액형  브랜드평판지수
# 7   소연   아이들  큐브  여자  1998-08-26 NaN   B  4668615
# 10  태연  소녀시대  SM  여자  1989-03-09 NaN   A  3918661

# %%
df.dropna()
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 14    슈가  방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
res=[]
s=['빅뱅','뉴이스트']
for i in df['그룹']:
    try:
        if i in s:
            res.append(None)
        else:
            res.append(i)
    except:
        res.append(None)

# %%
df['삭제여부']=res

# %%
df.dropna()
# Out:
#      이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수   삭제여부
# 0    지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  방탄소년단
# 3     뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  방탄소년단
# 4    화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928    마마무
# 5    정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  방탄소년단
# 8     진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  방탄소년단
# 9   하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     핫샷
# 11  차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027   아스트로
# 14   슈가  방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442  방탄소년단

# %%
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수   삭제여부
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  방탄소년단
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947   None
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745    NaN
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  방탄소년단
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928    마마무
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  방탄소년단
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792   None
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615    아이들
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  방탄소년단
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     핫샷
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661   소녀시대
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027   아스트로
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654   None
# ...

# %%
df=pd.read_csv('./data/korean-idol.csv')

# %%
df0[df0['그룹'].isin(['방탄소년단', '뉴이스트', '마마무'])]
# Out:
#        그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수   삭제여부
# 이름
# 지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260  방탄소년단
# 뷔   방탄소년단   빅히트  남자  1995-12-30  178.0  AB   8073501  방탄소년단
# 화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928    마마무
# 정국  방탄소년단   빅히트  남자  1997-09-01  178.0   A   5208335  방탄소년단
# 민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792   None
# 진   방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308  방탄소년단
# 백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654   None
# JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137   None
# 슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442  방탄소년단

# %%
cond1=df['그룹']=='방탄소년단'
cond2=df['그룹']=='뉴이스트'
cond3=df['그룹']=='마마무'
df[cond1 | cond2 | cond3]
# Out:
#     이름     그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0   지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260
# 3    뷔  방탄소년단   빅히트  남자  1995-12-30  178.0  AB   8073501
# 4   화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928
# 5   정국  방탄소년단   빅히트  남자  1997-09-01  178.0   A   5208335
# 6   민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792
# 8    진  방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308
# 12  백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654
# 13  JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137
# 14  슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
cond1=df['키']>=180
cond2=df['키']<=170

df[cond1 | cond2]
# Out:
#       이름    그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745
# 4     화사   마마무      RBW  여자  1995-07-23  162.1   A  7650928
# 6     민현  뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792
# 9    하성운    핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489
# 11   차은우  아스트로     판타지오  남자  1997-03-30  183.0   B  3506027

# %%
df=pd.read_csv('./data/korean-idol.csv')

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df.fillna(0),(df.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
# ----> 1 df.fill(0),(df.mean())
#
# File ~\miniconda3\envs\han\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'fill'

# %%
df.fillna(method='ffill')
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘     빅뱅      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26  182.3   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09  167.1   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1.fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 1>()
# ----> 1 df1.fillna(df1.mean())
#
# NameError: name 'df1' is not defined

# %%
df1['그룹'].fillna(method='ffill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 df1['그룹'].fillna(method='ffill')
#
# NameError: name 'df1' is not defined

# %%
df.describe()
# Out:
#                 키       브랜드평판지수
# count   13.000000  1.500000e+01
# mean   175.792308  5.655856e+06
# std      5.820576  2.539068e+06
# min    162.100000  2.925442e+06
# 25%    174.000000  3.712344e+06
# 50%    177.000000  4.668615e+06
# 75%    179.200000  7.862214e+06
# max    183.000000  1.052326e+07

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
#그룹의 그룹 빈도수가 가장 많은 데이터로 null 값을 구하세요
tmp = df1['그룹'].value_counts().sort_values(ascending=False)
df1['그룹'] = df1['그룹'].fillna(tmp.index[0])

# %%
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df=pd.read_csv('./data/korean-idol.csv')

# %%
max_freq=df['그룹'].value_counts().index[0]

# %%
df['그룹']=df['그룹'].fillna(max_freq)

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df=pd.read_csv('./data/korean-idol.csv')

temp=df[0:1]

temp.loc[0,['그룹','소속사','성별']]=None

temp

df0=pd.concat([df,temp])

# %%
df0
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민   None     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
df=pd.read_csv('./data/korean-idol.csv')

# %%
name=['그룹','소속사','성별']

for i in name:
    max_freq=df0[i].value_counts().index[0]
    df0[i]=df0[i].fillna(max_freq)

# %%
df0
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
#null이 있는 열이 어딨는지 확인할 때
#df.isnull().sum()
#null이 있는 전체 열 확인
#df[df.isnull().any(axis=1)]

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
name=['그룹','소속사','성별']
for i in name:
    freq=df1[i].value_counts().index[0] 
    df1[i]=df1[i].fillna(freq)

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
res=[]
# null이 있는 컬럼 필터링
# name=df1.columns
# name_null=name[df1.isnull().any()]

#null이 있는 컬럼중 'object'만 필터링
for i in name_null:
    if df1[i].dtypes=='object':
        res.append(i)

# 'object'형의 컬럼의 null에 최빈값 넣기
for i in res:
    freq=df1[i].value_counts().index[0]
    df1[i]=df1[i].fillna(freq)

# %%
df1=df.copy()

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1.dtypes
# Out:
# 이름          object
# 그룹          object
# 소속사         object
# 성별          object
# 생년월일        object
# 키          float64
# 혈액형         object
# 브랜드평판지수      int64
# dtype: object

# %%
#res로 담고 싶은 리스트 칸 만들고
#변수에 뽑고 싶은 거 넣기
#for i in 데이터 프레임:
#if 데이터 프레임[i].데이터 타입 in 변수
#res에 i 추가append
#출력 res
res=[]
fm=['float64','int64']
for i in df1:
    if df1[i].dtypes in fm:
        res.append(i)
print(res)

df1[res]
# Out:
# ['키', '브랜드평판지수']
#         키   브랜드평판지수
# 0   173.6  10523260
# 1   177.0   9916947
# 2   180.0   8273745
# 3   178.0   8073501
# 4   162.1   7650928
# 5   178.0   5208335
# 6   182.3   4989792
# 7     NaN   4668615
# 8   179.2   4570308
# 9   167.1   4036489
# 10    NaN   3918661
# 11  183.0   3506027
# 12  175.0   3301654
# 13  176.0   3274137
# 14  174.0   2925442

# %%
df1.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df1['키'].dtypes=='float64'
# Out:
# True

# %%
df.to_csv('null_df.csv')

# %%
df1.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df1.dtypes[df1.dtypes.isin(['float64','int64'])]
# Out:
# Series([], dtype: object)
