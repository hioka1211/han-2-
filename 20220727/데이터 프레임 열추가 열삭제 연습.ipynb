# %%
import pandas as pd

# %%
df=pd.read_csv('./data/cctv_in_seoul.csv')
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1=df.copy()

# %%
df1['기관명']
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 기관명, dtype: object

# %%
df1[['기관명','소계']]
# Out:
#      기관명    소계
# 0    강남구  3238
# 1    강동구  1010
# 2    강북구   831
# 3    강서구   911
# 4    관악구  2109
# 5    광진구   878
# 6    구로구  1884
# 7    금천구  1348
# 8    노원구  1566
# 9    도봉구   825
# 10  동대문구  1870
# 11   동작구  1302
# 12   마포구   980
# 13  서대문구  1254
# 14   서초구  2297
# 15   성동구  1327
# 16   성북구  1651
# 17   송파구  1081
# 18   양천구  2482
# 19  영등포구  1277
# 20   용산구  2096
# 21   은평구  2108
# 22   종로구  1619
# 23    중구  1023
# 24   중랑구   916

# %%
df1.head(3)
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204

# %%
df1.describe()
# Out:
#                 소계    2013년도 이전       2014년       2015년       2016년
# count    25.000000    25.000000   25.000000   25.000000   25.000000
# mean   1515.320000   764.760000  159.480000  205.200000  385.880000
# std     616.774656   415.510257  104.132976  137.877059  182.479981
# min     825.000000   238.000000   21.000000   30.000000   81.000000
# 25%    1010.000000   464.000000   78.000000  103.000000  292.000000
# 50%    1327.000000   573.000000  142.000000  184.000000  377.000000
# 75%    1884.000000  1070.000000  218.000000  269.000000  467.000000
# max    3238.000000  1843.000000  430.000000  584.000000  932.000000

# %%
df[df['소계']>=1884.000000]
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  3238       1292    430    584    932
# 4   관악구  2109        846    260    390    613
# 6   구로구  1884       1142    173    246    323
# 14  서초구  2297       1406    157    336    398
# 18  양천구  2482       1843    142     30    467
# 20  용산구  2096       1368    218    112    398
# 21  은평구  2108       1138    224    278    468

# %%
df1['비고']='연습'

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  비고
# 0  강남구  3238       1292    430    584    932  연습
# 1  강동구  1010        379     99    155    377  연습
# 2  강북구   831        369    120    138    204  연습
# 3  강서구   911        388    258    184     81  연습
# 4  관악구  2109        846    260    390    613  연습

# %%
df1['비고1']=''

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  비고 비고1
# 0  강남구  3238       1292    430    584    932  연습
# 1  강동구  1010        379     99    155    377  연습
# 2  강북구   831        369    120    138    204  연습
# 3  강서구   911        388    258    184     81  연습
# 4  관악구  2109        846    260    390    613  연습

# %%
df1.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년', '비고', '비고1'], dtype='object')

# %%
df1[['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년']]
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573     78     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348
# 24   중랑구   916        509    121    177    109

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  비고 비고1
# 0  강남구  3238       1292    430    584    932  연습
# 1  강동구  1010        379     99    155    377  연습
# 2  강북구   831        369    120    138    204  연습
# 3  강서구   911        388    258    184     81  연습
# 4  관악구  2109        846    260    390    613  연습

# %%
df1.iloc[:,:-2]
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573     78     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348
# 24   중랑구   916        509    121    177    109

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  비고 비고1
# 0  강남구  3238       1292    430    584    932  연습
# 1  강동구  1010        379     99    155    377  연습
# 2  강북구   831        369    120    138    204  연습
# 3  강서구   911        388    258    184     81  연습
# 4  관악구  2109        846    260    390    613  연습

# %%
df1=df1.loc[:,:'2016년']

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1['2014년'][1]
# Out:
# 99

# %%
df1.loc[1,'2014년'] #행과 열 구하기 #loc는 이름표라 자기를 포함함
# Out:
# 99

# %%
df.iloc[1,3] #행과 열 구하기
# Out:
# 99

# %%
df1.iloc[1:3,3:5]
# Out:
#    2014년  2015년
# 1     99    155
# 2    120    138

# %%
df1[['2014년','2015년']][1:3]
# Out:
#    2014년  2015년
# 1     99    155
# 2    120    138

# %%
df1.loc[1:2,'2014년':'2015년']
# Out:
#    2014년  2015년
# 1     99    155
# 2    120    138

# %%
df1['2014년'][1]=99
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11876\977851568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['2014년'][1]=99

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1.iloc[1,3]=200

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379    200    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1['2014년']
# Out:
# 0     430
# 1     200
# 2     120
# 3     258
# 4     260
# 5      78
# 6     173
# 7      51
# 8      57
# 9     159
# 10     23
# 11    341
# 12    118
# 13     50
# 14    157
# 15     91
# 16     78
# 17     21
# 18    142
# 19    214
# 20    218
# 21    224
# 22    314
# 23    190
# 24    121
# Name: 2014년, dtype: int64

# %%
df1['2014년'].value_counts()
# Out:
# 78     2
# 430    1
# 50     1
# 190    1
# 314    1
# 224    1
# 218    1
# 214    1
# 142    1
# 21     1
# 91     1
# 157    1
# 118    1
# 200    1
# 341    1
# 23     1
# 159    1
# 57     1
# 51     1
# 173    1
# 260    1
# 258    1
# 120    1
# 121    1
# Name: 2014년, dtype: int64

# %%
df1[df1['2014년']==78].loc[:,'2014년']=0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11876\2851533885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1['2014년']==78].loc[:,'2014년']=0

# %%
res=[]
for i in df1['2014년']:
    if i==78:
        res.append(0)
    else:
        res.append(i)
df1['2014년']=res

# %%
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379    200    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573      0     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009      0    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348
# 24   중랑구   916        509    121    177    109

# %%
df1['2014년']=[78 if i==0 else i for i in df['2014년']]

# %%
df1['기관명'].str[:2]
# Out:
# 0     강남
# 1     강동
# 2     강북
# 3     강서
# 4     관악
# 5     광진
# 6     구로
# 7     금천
# 8     노원
# 9     도봉
# 10    동대
# 11    동작
# 12    마포
# 13    서대
# 14    서초
# 15    성동
# 16    성북
# 17    송파
# 18    양천
# 19    영등
# 20    용산
# 21    은평
# 22    종로
# 23    중구
# 24    중랑
# Name: 기관명, dtype: object

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379    100    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1['2016증감']=df1['2016년']-df1['2015년']

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감
# 0  강남구  3238       1292    430    584    932  348     348
# 1  강동구  1010        379    100    155    377  222     222
# 2  강북구   831        369    120    138    204   66      66
# 3  강서구   911        388    258    184     81 -103    -103
# 4  관악구  2109        846    260    390    613  223     223

# %%
df1['증감_리스트내포']=['증가' if i>=0 else '감소' for i in df1['2016증감']]

# %%
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포
# 0    강남구  3238       1292    430    584    932  348     348       증가
# 1    강동구  1010        379    100    155    377  222     222       증가
# 2    강북구   831        369    120    138    204   66      66       증가
# 3    강서구   911        388    258    184     81 -103    -103       감소
# 4    관악구  2109        846    260    390    613  223     223       증가
# 5    광진구   878        573     78     53    174  121     121       증가
# 6    구로구  1884       1142    173    246    323   77      77       증가
# 7    금천구  1348        674     51    269    354   85      85       증가
# 8    노원구  1566        542     57    451    516   65      65       증가
# 9    도봉구   825        238    159     42    386  344     344       증가
# 10  동대문구  1870       1070     23    198    579  381     381       증가
# 11   동작구  1302        544    341    103    314  211     211       증가
# 12   마포구   980        314    118    169    379  210     210       증가
# 13  서대문구  1254        844     50     68    292  224     224       증가
# 14   서초구  2297       1406    157    336    398   62      62       증가
# 15   성동구  1327        730     91    241    265   24      24       증가
# 16   성북구  1651       1009     78    360    204 -156    -156       감소
# 17   송파구  1081        529     21     68    463  395     395       증가
# 18   양천구  2482       1843    142     30    467  437     437       증가
# 19  영등포구  1277        495    214    195    373  178     178       증가
# 20   용산구  2096       1368    218    112    398  286     286       증가
# 21   은평구  2108       1138    224    278    468  190     190       증가
# 22   종로구  1619        464    314    211    630  419     419       증가
# 23    중구  1023        413    190     72    348  276     276       증가
# 24   중랑구   916        509    121    177    109  -68     -68       감소

# %%
res=[]
for i in df1['2016증감']:
    if i>=0:
        res.append('증가')
    else:
        res.append('감소')
df1['증감_for']=res

# %%
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포 증감_for
# 0    강남구  3238       1292    430    584    932  348     348       증가     증가
# 1    강동구  1010        379    100    155    377  222     222       증가     증가
# 2    강북구   831        369    120    138    204   66      66       증가     증가
# 3    강서구   911        388    258    184     81 -103    -103       감소     감소
# 4    관악구  2109        846    260    390    613  223     223       증가     증가
# 5    광진구   878        573     78     53    174  121     121       증가     증가
# 6    구로구  1884       1142    173    246    323   77      77       증가     증가
# 7    금천구  1348        674     51    269    354   85      85       증가     증가
# 8    노원구  1566        542     57    451    516   65      65       증가     증가
# 9    도봉구   825        238    159     42    386  344     344       증가     증가
# 10  동대문구  1870       1070     23    198    579  381     381       증가     증가
# 11   동작구  1302        544    341    103    314  211     211       증가     증가
# 12   마포구   980        314    118    169    379  210     210       증가     증가
# 13  서대문구  1254        844     50     68    292  224     224       증가     증가
# 14   서초구  2297       1406    157    336    398   62      62       증가     증가
# 15   성동구  1327        730     91    241    265   24      24       증가     증가
# 16   성북구  1651       1009     78    360    204 -156    -156       감소     감소
# 17   송파구  1081        529     21     68    463  395     395       증가     증가
# 18   양천구  2482       1843    142     30    467  437     437       증가     증가
# 19  영등포구  1277        495    214    195    373  178     178       증가     증가
# 20   용산구  2096       1368    218    112    398  286     286       증가     증가
# 21   은평구  2108       1138    224    278    468  190     190       증가     증가
# 22   종로구  1619        464    314    211    630  419     419       증가     증가
# 23    중구  1023        413    190     72    348  276     276       증가     증가
# 24   중랑구   916        509    121    177    109  -68     -68       감소     감소

# %%
import matplotlib.pyplot as plt

# %%
df1['소계'].plot()
# Out:
# <AxesSubplot:>

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포 증감_for
# 0  강남구  3238       1292    430    584    932  348     348       증가     증가
# 1  강동구  1010        379    100    155    377  222     222       증가     증가
# 2  강북구   831        369    120    138    204   66      66       증가     증가
# 3  강서구   911        388    258    184     81 -103    -103       감소     감소
# 4  관악구  2109        846    260    390    613  223     223       증가     증가

# %%
df1.set_index('기관명',inplace=True)

# %%
df1.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포 증감_for
# 기관명
# 강남구  3238       1292    430    584    932  348     348       증가     증가
# 강동구  1010        379    100    155    377  222     222       증가     증가
# 강북구   831        369    120    138    204   66      66       증가     증가
# 강서구   911        388    258    184     81 -103    -103       감소     감소
# 관악구  2109        846    260    390    613  223     223       증가     증가

# %%
plt.figure(figsize=(15,6))
df1['소계'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='기관명'>

# %%
plt.figure(figsize=(15,6))
plt.plot(df1['소계'])
plt.xticks(rotation='90')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      -------------------------------------- 292.8/292.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in c:\users\user\miniconda3\envs\han\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\user\miniconda3\envs\han\lib\site-packages (from seaborn) (1.23.1)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp310-cp310-win_amd64.whl (36.9 MB)
#      --------------------------------------- 36.9/36.9 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.2 in c:\users\user\miniconda3\envs\han\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\envs\han\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\miniconda3\envs\han\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\envs\han\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.1 seaborn-0.11.2

# %%
df1['소계']
# Out:
# 0     3238
# 1     1010
# 2      831
# 3      911
# 4     2109
# 5      878
# 6     1884
# 7     1348
# 8     1566
# 9      825
# 10    1870
# 11    1302
# 12     980
# 13    1254
# 14    2297
# 15    1327
# 16    1651
# 17    1081
# 18    2482
# 19    1277
# 20    2096
# 21    2108
# 22    1619
# 23    1023
# 24     916
# Name: 소계, dtype: int64

# %%
df1['소계'].plot(kind='box')
plt.show()

# %%
df1.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포 증감_for
# 기관명
# 강남구  3238       1292    430    584    932  348     348       증가     증가
# 강동구  1010        379    100    155    377  222     222       증가     증가
# 강북구   831        369    120    138    204   66      66       증가     증가
# 강서구   911        388    258    184     81 -103    -103       감소     감소
# 관악구  2109        846    260    390    613  223     223       증가     증가

# %%
df1.drop('강남구')
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포 증감_for
# 기관명
# 강동구   1010        379    100    155    377  222     222       증가     증가
# 강북구    831        369    120    138    204   66      66       증가     증가
# 강서구    911        388    258    184     81 -103    -103       감소     감소
# 관악구   2109        846    260    390    613  223     223       증가     증가
# 광진구    878        573     78     53    174  121     121       증가     증가
# 구로구   1884       1142    173    246    323   77      77       증가     증가
# 금천구   1348        674     51    269    354   85      85       증가     증가
# 노원구   1566        542     57    451    516   65      65       증가     증가
# 도봉구    825        238    159     42    386  344     344       증가     증가
# 동대문구  1870       1070     23    198    579  381     381       증가     증가
# 동작구   1302        544    341    103    314  211     211       증가     증가
# 마포구    980        314    118    169    379  210     210       증가     증가
# 서대문구  1254        844     50     68    292  224     224       증가     증가
# 서초구   2297       1406    157    336    398   62      62       증가     증가
# 성동구   1327        730     91    241    265   24      24       증가     증가
# 성북구   1651       1009     78    360    204 -156    -156       감소     감소
# 송파구   1081        529     21     68    463  395     395       증가     증가
# 양천구   2482       1843    142     30    467  437     437       증가     증가
# 영등포구  1277        495    214    195    373  178     178       증가     증가
# 용산구   2096       1368    218    112    398  286     286       증가     증가
# 은평구   2108       1138    224    278    468  190     190       증가     증가
# 종로구   1619        464    314    211    630  419     419       증가     증가
# 중구    1023        413    190     72    348  276     276       증가     증가
# 중랑구    916        509    121    177    109  -68     -68       감소     감소

# %%
df1.drop('증감',axis=1)
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년  2016증감 증감_리스트내포 증감_for
# 기관명
# 강남구   3238       1292    430    584    932     348       증가     증가
# 강동구   1010        379    100    155    377     222       증가     증가
# 강북구    831        369    120    138    204      66       증가     증가
# 강서구    911        388    258    184     81    -103       감소     감소
# 관악구   2109        846    260    390    613     223       증가     증가
# 광진구    878        573     78     53    174     121       증가     증가
# 구로구   1884       1142    173    246    323      77       증가     증가
# 금천구   1348        674     51    269    354      85       증가     증가
# 노원구   1566        542     57    451    516      65       증가     증가
# 도봉구    825        238    159     42    386     344       증가     증가
# 동대문구  1870       1070     23    198    579     381       증가     증가
# 동작구   1302        544    341    103    314     211       증가     증가
# 마포구    980        314    118    169    379     210       증가     증가
# 서대문구  1254        844     50     68    292     224       증가     증가
# 서초구   2297       1406    157    336    398      62       증가     증가
# 성동구   1327        730     91    241    265      24       증가     증가
# 성북구   1651       1009     78    360    204    -156       감소     감소
# 송파구   1081        529     21     68    463     395       증가     증가
# 양천구   2482       1843    142     30    467     437       증가     증가
# 영등포구  1277        495    214    195    373     178       증가     증가
# 용산구   2096       1368    218    112    398     286       증가     증가
# 은평구   2108       1138    224    278    468     190       증가     증가
# 종로구   1619        464    314    211    630     419       증가     증가
# 중구    1023        413    190     72    348     276       증가     증가
# 중랑구    916        509    121    177    109     -68       감소     감소

# %%
del df1['증감_for']

# %%
df1.drop('강동구')
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포
# 기관명
# 강남구   3238       1292    430    584    932  348     348       증가
# 강북구    831        369    120    138    204   66      66       증가
# 강서구    911        388    258    184     81 -103    -103       감소
# 관악구   2109        846    260    390    613  223     223       증가
# 광진구    878        573     78     53    174  121     121       증가
# 구로구   1884       1142    173    246    323   77      77       증가
# 금천구   1348        674     51    269    354   85      85       증가
# 노원구   1566        542     57    451    516   65      65       증가
# 도봉구    825        238    159     42    386  344     344       증가
# 동대문구  1870       1070     23    198    579  381     381       증가
# 동작구   1302        544    341    103    314  211     211       증가
# 마포구    980        314    118    169    379  210     210       증가
# 서대문구  1254        844     50     68    292  224     224       증가
# 서초구   2297       1406    157    336    398   62      62       증가
# 성동구   1327        730     91    241    265   24      24       증가
# 성북구   1651       1009     78    360    204 -156    -156       감소
# 송파구   1081        529     21     68    463  395     395       증가
# 양천구   2482       1843    142     30    467  437     437       증가
# 영등포구  1277        495    214    195    373  178     178       증가
# 용산구   2096       1368    218    112    398  286     286       증가
# 은평구   2108       1138    224    278    468  190     190       증가
# 종로구   1619        464    314    211    630  419     419       증가
# 중구    1023        413    190     72    348  276     276       증가
# 중랑구    916        509    121    177    109  -68     -68       감소

# %%
df1
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포
# 기관명
# 강남구   3238       1292    430    584    932  348     348       증가
# 강동구   1010        379    100    155    377  222     222       증가
# 강북구    831        369    120    138    204   66      66       증가
# 강서구    911        388    258    184     81 -103    -103       감소
# 관악구   2109        846    260    390    613  223     223       증가
# 광진구    878        573     78     53    174  121     121       증가
# 구로구   1884       1142    173    246    323   77      77       증가
# 금천구   1348        674     51    269    354   85      85       증가
# 노원구   1566        542     57    451    516   65      65       증가
# 도봉구    825        238    159     42    386  344     344       증가
# 동대문구  1870       1070     23    198    579  381     381       증가
# 동작구   1302        544    341    103    314  211     211       증가
# 마포구    980        314    118    169    379  210     210       증가
# 서대문구  1254        844     50     68    292  224     224       증가
# 서초구   2297       1406    157    336    398   62      62       증가
# 성동구   1327        730     91    241    265   24      24       증가
# 성북구   1651       1009     78    360    204 -156    -156       감소
# 송파구   1081        529     21     68    463  395     395       증가
# 양천구   2482       1843    142     30    467  437     437       증가
# 영등포구  1277        495    214    195    373  178     178       증가
# 용산구   2096       1368    218    112    398  286     286       증가
# 은평구   2108       1138    224    278    468  190     190       증가
# 종로구   1619        464    314    211    630  419     419       증가
# 중구    1023        413    190     72    348  276     276       증가
# 중랑구    916        509    121    177    109  -68     -68       감소

# %%
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포
# 기관명
# 강남구   3238       1292    430    584    932  348     348       증가
# 강북구    831        369    120    138    204   66      66       증가
# 강서구    911        388    258    184     81 -103    -103       감소
# 관악구   2109        846    260    390    613  223     223       증가
# 광진구    878        573     78     53    174  121     121       증가
# 구로구   1884       1142    173    246    323   77      77       증가
# 금천구   1348        674     51    269    354   85      85       증가
# 노원구   1566        542     57    451    516   65      65       증가
# 도봉구    825        238    159     42    386  344     344       증가
# 동대문구  1870       1070     23    198    579  381     381       증가
# 동작구   1302        544    341    103    314  211     211       증가
# 마포구    980        314    118    169    379  210     210       증가
# 서대문구  1254        844     50     68    292  224     224       증가
# 서초구   2297       1406    157    336    398   62      62       증가
# 성동구   1327        730     91    241    265   24      24       증가
# 성북구   1651       1009     78    360    204 -156    -156       감소
# 송파구   1081        529     21     68    463  395     395       증가
# 양천구   2482       1843    142     30    467  437     437       증가
# 영등포구  1277        495    214    195    373  178     178       증가
# 용산구   2096       1368    218    112    398  286     286       증가
# 은평구   2108       1138    224    278    468  190     190       증가
# 종로구   1619        464    314    211    630  419     419       증가
# 중구    1023        413    190     72    348  276     276       증가
# 중랑구    916        509    121    177    109  -68     -68       감소

# %%
df1.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년   증감  2016증감 증감_리스트내포
# 기관명
# 강남구  3238       1292    430    584    932  348     348       증가
# 강동구  1010        379    100    155    377  222     222       증가
# 강북구   831        369    120    138    204   66      66       증가
# 강서구   911        388    258    184     81 -103    -103       감소
# 관악구  2109        846    260    390    613  223     223       증가

# %%
df1.iloc[:,1:-2].values.sum()
# Out:
# 42401

# %%
df1.iloc[:1:-2].sum(axis=1).sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11876\2314454622.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.iloc[:1:-2].sum(axis=1).sum()
# 44606

# %%
df1.iloc[:,:-1].sum()
# Out:
# 소계           37883
# 2013년도 이전    19119
# 2014년         3988
# 2015년         5130
# 2016년         9647
# 증감            4517
# 2016증감        4517
# dtype: int64
